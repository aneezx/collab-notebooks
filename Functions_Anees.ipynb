# %%
for i in range(1, 11):
    if i == 3 or i == 6:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 9
# 10

# %%
for i in range(1, 13):
    if i % 4 == 0:
        break
    print(i)
# Out:
# 1
# 2
# 3

# %%
def add(a,b):
  return a+b

add(7,4)
# Out:
# 11

# %%
def Simple():
  print('No parameter function')

Simple()
# Out:
# No parameter function

# %%
x = 101 #Global scope
def func():
  x = 102 #Local scope
  print('Inside func',x)

func()
print('Outside func', x)
# Out:
# Inside func 102
# Outside func 101
