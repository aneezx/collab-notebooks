# %% [markdown]
# #Python Variables

# %%
a=15
print(a)
type(a)
display(a)
# Out:
# 15
# 15

# %%
b=1 + 5j
print(b)
type(b)
display(b)
# Out:
# (1+5j)
# (1+5j)

# %%
x = 'Indian Ocean'
y = x[0:5]
z = x[-5:]

print(y)
print(z)
# Out:
# India
# Ocean
